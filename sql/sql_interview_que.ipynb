-- %%
%sql
-- Create table
CREATE TABLE Employees_s (
    id INT
);

-- Insert data

-- %%
%sql
INSERT INTO Employees_s (id) VALUES
(2),
(5),
(6),
(6),
(7),
(8),
(8);

-- %%
select * from employees_s;

-- %%
select * , row_number() over (partition by id ) as rn from employees_s;
